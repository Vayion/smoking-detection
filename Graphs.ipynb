# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


df = pd.read_csv("./dataset/dataset.csv")

# %%
smokers = df[df["smoking"]==1]
clean = df[df["smoking"]==0]

avg_smokers = smokers.groupby(label_x)[label_y].mean()
avg_clean = clean.groupby(label_x)[label_y].mean()

fig, ax = plt.subplots()

ax.plot(avg_smokers.index, avg_smokers.values, linewidth=2.0, label = "smokers")
ax.plot(avg_clean.index, avg_clean.values, linewidth=2.0, label = "non smokers")
ax.set_xlabel(label_x)
ax.set_ylabel(label_y)
ax.legend()

# %%
tg_smoker = smokers["triglyceride"]
tg_nonsmoker = clean["triglyceride"]

log_tg_smoker = np.log1p(tg_smoker)
log_tg_nonsmoker = np.log1p(tg_nonsmoker)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.hist(tg_nonsmoker, bins=50, alpha=0.6, label="Non-smokers")
plt.hist(tg_smoker, bins=50, alpha=0.6, label="Smokers")
plt.xlabel("Triglyceride")
plt.ylabel("Count")
plt.title("Raw Triglycerides")
plt.legend()

plt.subplot(1, 2, 2)
plt.hist(log_tg_nonsmoker, bins=50, alpha=0.6, label="Non-smokers")
plt.hist(log_tg_smoker, bins=50, alpha=0.6, label="Smokers")
plt.xlabel("log(Triglyceride + 1)")
plt.ylabel("Count")
plt.title("Log-Transformed Triglycerides")
plt.legend()

plt.tight_layout()
plt.show()

# %%
def plot_feature_distribution(category, bins=100):
    
    dfs=[
        df_women_smoking,
        df_women_nonsmoking,
        df_men_smoking,
        df_men_nonsmoking
    ]
    labels=[
        "Women – Smoking",
        "Women – Non-smoking",
        "Men – Smoking",
        "Men – Non-smoking"
    ]
    
    plt.figure(figsize=(8, 6))

    data = []
    for df in dfs:
        values = df[category].dropna()
        data.append(values)

    plt.boxplot(
        data,
        labels=labels,
        showfliers=True,   # Punkte für Ausreißer
        patch_artist=True
    )

    plt.ylabel(category)
    plt.title(category + " Distribution by Sex and Smoking Status")
    plt.xticks(rotation=20)
    plt.tight_layout()
    plt.show()

# %%
smokers = df[df["smoking"]==1]
clean = df[df["smoking"]==0]

df_women_smoking = smokers[smokers["gender"]==0]
df_women_nonsmoking = clean[clean["gender"]==0]
df_men_smoking = smokers[smokers["gender"]==1]
df_men_nonsmoking = clean[clean["gender"]==1]

# %%
plot_feature_distribution(
    category = "triglyceride"
)
# Out:
# C:\Users\Tom\AppData\Local\Temp\ipykernel_21464\920778189.py:23: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %%
plot_feature_distribution(
    category = "HDL"
)
# Out:
# C:\Users\Tom\AppData\Local\Temp\ipykernel_21464\4210579385.py:10: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %%
plot_feature_distribution(
    category = "LDL"
)
# Out:
# C:\Users\Tom\AppData\Local\Temp\ipykernel_21464\4210579385.py:10: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %%
plot_feature_distribution(
    category = "Gtp"
)
# Out:
# C:\Users\Tom\AppData\Local\Temp\ipykernel_21464\920778189.py:23: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(
