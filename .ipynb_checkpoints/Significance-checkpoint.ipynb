# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv("./dataset/dataset.csv")
y = df.pop("smoking").astype(int)
X = df

# %%
import pandas as pd
import statsmodels.api as sm
from sklearn.preprocessing import RobustScaler


#Robust Scaler to ignore all extreme outliers
scaler = RobustScaler()
X_scaled = scaler.fit_transform(X)
X = pd.DataFrame(
    X_scaled,
    columns = X.columns,
    index = X.index
)

X = sm.add_constant(X)

model = sm.Logit(y, X)
result = model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.641947
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                smoking   No. Observations:                71056
# Model:                          Logit   Df Residuals:                    71031
# Method:                           MLE   Df Model:                           24
# Date:                Tue, 13 Jan 2026   Pseudo R-squ.:                 0.07387
# Time:                        21:05:47   Log-Likelihood:                -45614.
# converged:                       True   LL-Null:                       -49252.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.3564      0.024    -14.695      0.000      -0.404      -0.309
# gender                 -0.6038      0.032    -19.058      0.000      -0.666      -0.542
# age                    -0.0851      0.009     -9.425      0.000      -0.103      -0.067
# height(cm)              0.4538      0.025     18.242      0.000       0.405       0.503
# weight(kg)             -0.2040      0.024     -8.511      0.000      -0.251      -0.157
# waist(cm)               0.0526      0.023      2.252      0.024       0.007       0.098
# eyesight(left)         -0.0446      0.008     -5.541      0.000      -0.060      -0.029
# eyesight(right)        -0.0299      0.008     -3.920      0.000      -0.045      -0.015
# hearing(left)          -0.0721      0.059     -1.220      0.222      -0.188       0.044
# hearing(right)          0.1297      0.057      2.260      0.024       0.017       0.242
# systolic               -0.3622      0.019    -19.483      0.000      -0.399      -0.326
# relaxation              0.1068      0.015      6.977      0.000       0.077       0.137
# fasting blood sugar     0.0602      0.007      8.986      0.000       0.047       0.073
# Cholesterol            -0.1971      0.023     -8.694      0.000      -0.242      -0.153
# triglyceride            0.4866      0.014     33.939      0.000       0.459       0.515
# HDL                     0.1405      0.015      9.628      0.000       0.112       0.169
# LDL                    -0.0007      0.018     -0.038      0.969      -0.037       0.035
# hemoglobin              0.3731      0.016     23.343      0.000       0.342       0.404
# Urine protein           0.0097      0.020      0.483      0.629      -0.030       0.049
# serum creatinine       -0.1766      0.016    -11.386      0.000      -0.207      -0.146
# AST                    -0.0233      0.009     -2.498      0.013      -0.042      -0.005
# ALT                    -0.1114      0.011    -10.046      0.000      -0.133      -0.090
# Gtp                     0.2286      0.007     30.509      0.000       0.214       0.243
# dental caries           0.3563      0.020     18.183      0.000       0.318       0.395
# tartar                 -0.4103      0.016    -25.264      0.000      -0.442      -0.378
# =======================================================================================
